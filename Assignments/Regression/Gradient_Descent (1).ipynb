# %% [markdown]
# # Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5, 6, 8, 10])
y = np.array([5, 7, 9, 11, 13, 18, 20, 22])

# %%
plt.scatter(x,y)
plt.show()

# %%
def gradient_descent(x,y):
    w0 = 0
    w1 = 0
    iterations = 1000 # epochs
    n = len(x)
    eta = 0.001
    for i in range(iterations):
        y_pred = w0 + w1*x
        cost = (1/n)*sum(val**2 for val in (y-y_pred))
        w0_D = -(2/n)*sum((y-y_pred))
        w1_D = -(2/n)*sum(x*(y-y_pred))
            w0 = w0 - eta * w0_D
        w1 = w1 - eta * w1_D
        print("w0{},w1{},iteration{},cost{}".format(w0,w1,i,cost))

gradient_descent(x,y)
# Out:
# w00.02625,w10.16075,iteration0,cost206.625
# w00.05088018750000001,w10.31099625,iteration1,cost180.96087394531253
# w00.0739962136875,w10.451424157234375,iteration2,cost158.5365237993558
# w00.09569683572708985,w10.5826744041272305,iteration3,cost138.9429350796366
# w00.11607436661539518,w10.7053458667157804,iteration4,cost121.82273050278528
# w00.13521509568168552,w10.8199983426381493,iteration5,cost106.8636508991421
# w00.15319968164960018,w10.9271551011120709,iteration6,cost93.79285914786702
# w00.17010352005045828,w11.0273052665200928,iteration7,cost82.37196322799986
# w00.18599708666178646,w11.1209060464589449,iteration8,cost72.39266759862807
# w00.20094625853548817,w11.2083848144022347,iteration9,cost63.67297358296269
# w00.2150126140779954,w11.2901410564633713,iteration10,cost56.05385944575841
# w00.22825371354932156,w11.3665481911265709,iteration11,cost49.396379603824826
# w00.24072336125873886,w11.4379552702351461,iteration12,cost43.57913005497617
# ...

# %%
y_pred = 1.513071753770061 + 2.2922714333885965*x

# %%
plt.scatter(x, y)
plt.plot([min(x),max(x)],[min(y_pred),max(y_pred)],color = 'red')
#plt.plot([0-x1,4-x2],[0-y1,5-y2],color = 'red')
plt.show()

# %%
y= np.array([1,2,3,5])
y_pred = np.array([1,4,9,7])
sum(val**2 for val in (y-y_pred))
# Out:
# 44
